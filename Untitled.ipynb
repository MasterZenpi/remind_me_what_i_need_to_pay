# %%
import pandas as pd

# %%
data = pd.read_csv("laon.csv")

# %%
data
# Out:
#     Payment Number Payment\nDate Beginning\nBalance Scheduled Payment  \
# 0                1      8/6/2022         $8,459.00           $253.25
# 1                2      9/6/2022         $8,216.00           $253.25
# 2                3     10/6/2022         $7,971.98           $253.25
# 3                4     11/6/2022         $7,726.95           $253.25
# 4                5     12/6/2022         $7,480.89           $253.25
# 5                6      1/6/2023         $7,233.81           $253.25
# 6                7      2/6/2023         $6,985.70           $253.25
# 7                8      3/6/2023         $6,736.56           $253.25
# 8                9      4/6/2023         $6,486.38           $253.25
# 9               10      5/6/2023         $6,235.16           $253.25
# 10              11      6/6/2023         $5,982.89           $253.25
# 11              12      7/6/2023         $5,729.56           $253.25
# 12              13      8/6/2023         $5,475.19           $253.25
# ...
